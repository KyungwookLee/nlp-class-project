# %%
import torch
from torch.utils.data import DataLoader

from transformers import BertForSequenceClassification, BertTokenizerFast
from bertviz.bertviz import head_view
from tqdm import tqdm, trange

import utils
from dataset import MBTIDataset

# %%
# %%javascript
# require.config({
#   paths: {
#       d3: '//cdnjs.cloudflare.com/ajax/libs/d3/3.4.8/d3.min',
#       jquery: '//ajax.googleapis.com/ajax/libs/jquery/2.0.0/jquery.min',
#   }
# });

# %%
# Load fine-tuned model & test set
model = BertForSequenceClassification.from_pretrained('./checkpoint', num_labels=16, output_attentions=True)
tokenizer = BertTokenizerFast.from_pretrained('bert-base-uncased')
test_set = MBTIDataset('100speeches.tsv', tokenizer)
# Out:
# Reading 100speeches.tsv: 69it [00:00, 99.12it/s]

# %%
def get_attentions_from_correct_examples(model, test_set, tokenizer):
    attentions, tok_texts, labels = [], [], []
    model.eval()
    with torch.no_grad():
        for post, label in tqdm(test_set, desc="Testing Iteration"):
            logit, attention = model(torch.tensor(post).unsqueeze(0))
            pred = torch.argmax(logit[0].data)
            if pred.item() == label:
                tokens = tokenizer.convert_ids_to_tokens(post)
                attentions.append(attention)
                tok_texts.append(tokens)
                labels.append(utils.decode_label(label))
    return attentions, tok_texts, labels

# %%
attentions, tok_texts, labels = get_attentions_from_correct_examples(model, test_set, tokenizer)
# Out:
# Testing Iteration: 100%|██████████| 69/69 [00:18<00:00,  3.80it/s]

# %%
examples = list(range(5))
layer = 0
heads = list(range(12))
for example in examples:
    print(labels[example])
    print("\n\n")
    for head in heads:
        layer_val, layer_ind = torch.topk(attentions[example][layer][0,head,:,0], k=20) # attention[example][layer][batch,head,seq,seq]
        top_tokens = [tok_texts[example][i] for i in layer_ind]
        print(top_tokens)
        print()

# example = 4
# layer = 1
# head = 6
# print(labels[example])
# # print(tok_texts[example])
# print(tokenizer.decode(tokenizer.convert_tokens_to_ids(tok_texts[example])))
# layer_val, layer_ind = torch.topk(attentions[example][layer][0,head,:,0], k=20) # attention[example][layer][batch,head,seq,seq]
# top_tokens = [tok_texts[example][i] for i in layer_ind]
# print(layer_val)
# print(layer_ind)
# print(top_tokens)
# Out:
# INTJ
#
#
#
# ['were', 'of', 'by', 'haven', 'thought', 'and', 'with', 'identity', 'i', 'within', 'of', 'to', 'or', '[SEP]', 'of', ',', 'to', 'to', 'principle', 'help']
#
# ['##to', '##pha', '##rea', '##iger', '##her', '##ents', '##ved', '##ager', '##d', 'ha', '##scribe', '##zard', '##d', '##s', 'bell', '##scribe', '[CLS]', '##rand', '##ly', '##ly']
#
# ['gentlemen', 'february', 'february', 'assume', 'april', 'conform', 'sunk', 'imperial', 'imperial', 'neutral', 'earlier', 'officially', 'extraordinary', 'principle', 'constitutional', 'submarines', 'compassion', 'german', 'highways', 'submarines']
#
# ['gentlemen', '[SEP]', 'assume', 'constitutional', '[SEP]', '[CLS]', 'commanders', '##sea', 'conform', 'dominion', 'laid', 'imperial', 'somewhat', 'reckless', 'officially', 'neither', 'imperial', 'extraordinary', '[SEP]', 'per']
#
# ['##zard', '##ents', '##scribe', '##scribe', '[CLS]', 'seas', '##ager', 'upon', 'sub', 'attempt', 'warning', 'observed', 'sunk', 'vessels', 'highways', 'humane', 'cargo', 'sunk', '##rand', 'stricken']
#
# ['and', 'and', 'and', '##rand', ',', 'the', 'reckless', 'and', '[SEP]', 'the', '[SEP]', ',', 'the', '[SEP]', '[SEP]', 'and', 'and', 'and', 'or', '##to']
#
# ['ports', 'ports', '##man', 'distress', 'restriction', 'progress', 'belgium', 'vessels', '##ents', 'government', 'government', 'cargo', 'policy', 'business', 'un', 'observed', 'practices', 'pro', 'britain', 'conduct']
#
# ['the', 'little', 'the', 'of', 'the', 'the', 'to', 'of', 'of', 'the', 'the', 'been', 'compassion', 'unmistakable', 'up', '##to', 'to', 'and', 'of', 'done']
#
# ['[SEP]', '[CLS]', '[SEP]', '[SEP]', '[SEP]', 'nor', '##her', '[SEP]', '##rand', '##pha', 'submarine', 'congress', 'nation', '[SEP]', 'bell', 'er', 'german', 'humane', 'april', 'distress']
#
# ['every', 'every', 'been', 'along', 'of', 'been', 'same', 'of', 'of', 'of', 'of', 'since', 'of', 'of', 'of', 'as', ',', 'instance', '[SEP]', '[SEP]']
#
# ['submarines', 'britain', 'highways', 'precautions', 'enemies', '##missible', 'vessels', 'choices', 'europe', 'boats', 'belgium', 'restraints', 'commanders', '[CLS]', 'nation', 'coasts', 'destination', 'escape', 'crews', 'restrained']
#
# ['[SEP]', '[SEP]', 'the', 'the', ',', 'the', '[SEP]', 'the', ',', 'the', 'compassion', 'the', ',', '[SEP]', 'the', 'the', 'the', 'destroy', 'the', 'the']
#
# INFJ
#
#
#
# ['than', 'of', '[SEP]', 'more', 'is', 'in', 'truth', 'much', 'very', 'your', 'is', 'still', 'of', 'your', 'and', 'and', 'so', 'civilization', 'the', '[SEP]']
#
# ['##ss', '##ile', '##mmon', '##ic', 'des', 'sep', 'sep', 'sep', '##able', 'sep', '##d', '##est', 'pal', 'pri', '##ed', 'sep', 'sep', 'ma', '##try', 'flesh']
#
# ['listened', 'espionage', 'your', 'unchanged', 'compelled', 'opposed', 'i', 'i', 'recognized', 'fourteen', 'my', 'possible', 'we', 'i', 'firing', 'robbed', 'my', 'sep', 'forced', 'conflict']
#
# ['your', 'sep', '[SEP]', 'sep', '[CLS]', '[SEP]', 'sep', '[SEP]', '[SEP]', 'ago', 'institutions', 'freight', '[SEP]', 'fundamental', '[SEP]', 'social', 'sep', '[SEP]', '[SEP]', 'ma']
#
# ['##rant', '##mmon', 'sep', 'remorse', 'sep', 'sep', 'starved', 'sep', 'sep', 'sep', '[CLS]', 'robbed', '##ic', 'compelled', 'barren', 'ago', 'pit', '##hood', 'institutions', 'dwarf']
#
# ['sep', 'sep', 'sep', 'sep', 'and', 'sep', '##ss', '-', 'and', 'sep', 'and', '##ile', '-', 'and', 'and', 'and', 'and', '[SEP]', '[SEP]', 'ma']
#
# ['##vation', 'congress', 'railroad', 'wage', 'affairs', 'factories', 'railroads', 'compelled', 'railroad', '##try', 'tender', 'enactment', 'hardship', 'mills', 'unchanged', 'prosecution', 'to', 'firing', 'working', 'long']
#
# ['##ed', 'the', 'barren', 'truth', '##ed', 'grasp', 'this', 'noon', 'the', 'much', 'the', 'into', 'to', '[SEP]', 'the', 'starved', 'so', 'this', 'of', 'childhood']
#
# ['[SEP]', '[SEP]', '[SEP]', '[CLS]', '##ile', 'remorse', '##ss', '[SEP]', 'industrial', '[SEP]', '[SEP]', '[SEP]', '[SEP]', '[SEP]', 'sep', 'hardship', 'christian', 'ma', '##est', '##less']
#
# ['been', 'are', 'of', 'of', 'been', 'are', 'of', 'of', 'of', 'are', 'until', 'for', '[SEP]', 'of', 'earlier', 'in', 'in', 'of', 'has', 'of']
#
# ['espionage', '##vation', 'factories', 'machines', 'railroads', 'dungeons', 'justification', '[CLS]', 'starved', 'civilization', 'unchanged', 'beings', 'compelled', 'thinking', 'principles', 'railroad', 'industrial', 'monster', 'mines', 'system']
#
# ['the', ',', '[SEP]', 'the', 'grasp', '[SEP]', 'the', '[SEP]', 'to', ',', ',', '[SEP]', '[CLS]', 'the', '[SEP]', ',', '[SEP]', 'and', '[SEP]', 'the']
#
# INTJ
#
#
#
# ['of', 'to', '[SEP]', 'and', 'necessary', 'the', 'no', 'the', ',', 'earth', 'trouble', 'mother', 'blast', 'the', 'in', 'after', 'upon', 'all', 'be', 'to']
#
# ['##al', '##ct', '##im', '##rk', '##rk', '##um', '##a', '##rk', '##al', '##sy', 'ze', '##al', 'san', '##ffi', '##y', '##ce', 'mere', 'fl', 'su', '##ers']
#
# ['interfere', 'alexander', 'gentlemen', 'employed', 'mccarthy', 'disturb', 'emma', 'anarchist', 'satisfy', 'judges', 'officials', 'highly', 'anarchist', 'disturb', 'our', 'pity', 'also', 'military', 'camping', 'bail']
#
# ['gentlemen', '[SEP]', '[SEP]', 'ze', '[SEP]', 'camping', 'ashore', '[SEP]', '[SEP]', 'anarchist', 'alexander', 'anarchist', '[SEP]', 'co', '[CLS]', 'fl', 'defendant', 'heavily', 'jury', '[SEP]']
#
# ['neither', 'merely', '[CLS]', 'upon', 'habit', 'conscription', '##rily', '##script', 'upon', 'nor', 'hence', 'mere', 'attorney', '##rk', '##ffi', 'staged', 'ashore', 'warrant', '##hood', 'wasted']
#
# ['marsh', 'and', 'and', '-', '-', 'and', '##sy', '-', 'ze', 'and', 'anarchist', 'and', '##ct', ',', '[SEP]', 'anarchist', '##a', '[SEP]', '&', '-']
#
# ['famous', 'district', '##rily', 'employed', 'interfere', '##man', 'heroes', 'required', 'flights', 'faithful', 'fish', 'camping', '&', 'district', 'warrant', '##um', 'arrest', 'warrant', 'to', 'european']
#
# ['hiding', 'far', 'know', 'the', 'the', 'of', 'to', 'the', '##al', 'and', 'of', 'the', 'the', 'what', 'of', 'the', 'trouble', 'to', 'of', 'emma']
#
# ['[SEP]', '[SEP]', '[SEP]', '[SEP]', '[SEP]', '##sy', '[CLS]', '##rk', '[SEP]', '##rk', '##rk', '##im', '##ce', '[SEP]', '[SEP]', 'anarchist', '[SEP]', 'anarchist', '[SEP]', '[SEP]']
#
# ['of', '[SEP]', '##rk', 'of', 'of', 'of', 'in', 'of', 'of', 'is', 'of', 'merely', 'of', 'to', 'a', 'appropriate', 'to', '[SEP]', 'only', '[SEP]']
#
# ['officials', '##script', 'officers', 'anarchist', 'ashore', 'dealings', 'warriors', 'privacy', 'wielding', 'defendant', 'makers', 'camping', 'anarchist', 'hiding', 'training', 'interfere', 'arrest', 'faithful', 'alexander', 'offices']
#
# ['[SEP]', '[SEP]', ',', ',', '[SEP]', 'and', 'the', 'the', 'the', ',', 'the', 'them', ',', 'the', 'the', '[SEP]', '[SEP]', 'and', 'the', 'the']
#
# INFJ
#
#
#
# ['you', 'them', '[SEP]', 'i', 'i', 'them', 'of', 'have', 'wish', 'not', '[SEP]', '[SEP]', 'hope', 'hope', 'you', 'about', '[SEP]', ',', 'you', 'like']
#
# ['##mo', '##re', '##k', '##za', '##or', '##ve', '##ve', '##t', '##s', '##t', '##how', '##s', 'dreaming', 'mans', 'eat', '[CLS]', 'st', 'intellectual', 'mushroom', 'mans']
#
# ['indira', 'rare', 'graduating', 'commencement', 'graduating', 'everybody', 'greek', 'i', 'speak', 'we', 'poverty', '83', 'ronald', 'pregnant', 'thank', 'reality', 'dumb', 'we', 'wearing', '[SEP]']
#
# ['[SEP]', 'i', 'aloud', '[SEP]', '[SEP]', 'graduating', '[CLS]', 'dumb', 'greek', 'exclude', 'thank', 'tribal', 'commencement', 'ourselves', 'greek', '[SEP]', 'poverty', '[SEP]', 'horde', '[SEP]']
#
# ['[CLS]', 'dreaming', 'ivory', 'terrible', 'terrible', 'thirty', '##za', 'dumb', 'indira', 'ought', 'saying', 'triumphant', 'instead', 'yourself', '##k', '##mo', 'gandhi', 'tradition', 'twelfth', 'dresses']
#
# ['##za', '##re', '##mo', 'and', 'and', '-', '-', 'and', 'and', ',', '##k', '-', '##or', 'and', 'and', '[SEP]', ',', '[SEP]', 'and', 'the']
#
# ['selling', 'college', 'tribal', 'poverty', 'yours', 'graduating', 'theirs', '-', '[CLS]', 'talks', 'language', 'ought', 'don', 'go', 'say', 'twelfth', '##ve', 'including', 'long', 'doing']
#
# ['warm', '##k', 'beautiful', 'to', 'and', '-', 'and', 'the', 'somebody', '[SEP]', '[SEP]', 'to', 'ourselves', 'real', ',', 'and', '[SEP]', 'of', 'keep', 'the']
#
# ['[SEP]', '[SEP]', '[SEP]', '[SEP]', '[SEP]', '[SEP]', '[CLS]', '[SEP]', '[SEP]', '[SEP]', '[SEP]', '##ve', '[SEP]', '##za', '##k', '##ve', '[SEP]', '[SEP]', '[SEP]', '[SEP]']
#
# ['of', 'including', 'most', 'of', '##ve', 'of', 'of', 'least', '[SEP]', 'of', 'a', 'most', '[SEP]', 'of', 'instead', '[SEP]', '[SEP]', '##ve', 'of', 'from']
#
# ['poverty', 'success', 'century', 'gandhi', 'reality', 'exclude', 'indira', 'tribe', 'thatcher', 'dresses', 'awake', 'reagan', '[CLS]', 'husband', 'unspoken', 'tower', 'ourselves', 'pregnant', 'tragedy', 'tribal']
#
# ['[SEP]', '[SEP]', 'the', 'the', ',', '[SEP]', '[SEP]', ',', '[SEP]', 'the', '[SEP]', ',', '[SEP]', ',', '[SEP]', ',', ',', '[SEP]', '[SEP]', '[CLS]']
#
# INFJ
#
#
#
# ['in', 'needed', ',', 'pakistan', ')', ',', ',', ',', 'to', 'that', 'eritrea', ',', 'and', 'and', '[SEP]', 'sense', 'and', 'ireland', 'and', 'to']
#
# ['##at', '##ym', '##bin', '##bat', '##chen', '##lag', '##fa', '##a', '##ng', '##bl', '##idi', '##len', '##lb', '##hs', '##rook', 'tre', '##ink', '##e', 'ho', '##ish']
#
# ['mr', 'woke', 'mrs', 'compassion', 'dusk', 'judged', 'excel', 'judged', 'eritrea', 'mr', 'grateful', '[SEP]', 'kosovo', 'mrs', 'jewish', 'fifty', 'hillary', 'he', 'pakistan', 'thousands']
#
# ['mr', '[SEP]', 'bu', 'weimar', '[SEP]', 'rwanda', 'goethe', 'eternal', 'mrs', 'woke', 'ho', 'clinton', '[SEP]', '##rook', 'jewish', 'blur', '[CLS]', 'ra', 'hillary', '[SEP]']
#
# ['difference', 'severely', 'cher', 'surely', 'hiroshima', 'unnatural', '[CLS]', 'compassion', 'rwanda', '##ym', 'cambodia', 'sarajevo', 'destiny', 'ethiopia', 'algeria', 'hillary', 'et', 'threshold', 'kosovo', 'auschwitz']
#
# ['and', '-', 'and', 'and', '-', '##ym', 'and', '-', '-', '##at', '-', '-', 'and', 'and', 'et', 'and', 'and', 'and', '-', 'and']
#
# ['clinton', 'threshold', 'hiroshima', 'society', 'terms', 'gandhi', 'ab', 'profound', 'doing', 'jewish', 'tens', 'homeless', 'chain', 'auschwitz', 'liberated', 'freed', 'kosovo', 'injustice', '[SEP]', 'severely']
#
# ['before', 'the', 'it', 'much', 'this', 'bear', 'the', 'and', 'what', 'it', '##a', 'dark', 'of', 'and', 'on', '[SEP]', '##e', 'be', 'the', 'what']
#
# ['[SEP]', '[SEP]', 'cambodia', '[SEP]', 'gu', '[CLS]', '[SEP]', '[SEP]', '[SEP]', '##lb', '##bat', '[SEP]', 'moral', 'cruelty', '[SEP]', '[SEP]', '[SEP]', '[SEP]', '##ym', '##at']
#
# ['of', 'of', 'of', 'of', 'of', 'of', '[SEP]', 'of', 'of', 'are', 'in', 'of', '##hs', 'in', 'are', 'and', 'a', '[SEP]', '[SEP]', ',']
#
# ['compassion', 'dusk', 'punishment', 'clinton', 'ambassador', 'victims', 'remembers', 'darkness', 'vanishing', 'algeria', 'cambodia', 'victims', '##wald', 'woke', 'failures', '[CLS]', 'cruelty', 'goethe', 'liberated', 'century']
#
# ['[SEP]', '[SEP]', ',', ',', 'compassion', ',', ',', ',', '[SEP]', '[SEP]', ',', ',', ',', ',', 'and', 'the', '[SEP]', 'the', '[SEP]', ',']

# %%
# head_view([layer[:,:,layer_ind,:20] for layer in attentions[example]], top_tokens)

# %%
head_view([layer[:, :, torch.cat([torch.zeros(1, dtype=torch.long), layer_ind]), :21] for layer in attentions[example]], ['[CLS]'] + top_tokens)
# Out:
#               <span style="user-select:none">
#                 Layer: <select id="layer"></select>
#               </span>
#               <div id='vis'></div>
